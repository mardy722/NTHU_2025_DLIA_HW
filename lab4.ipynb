# %% [markdown]
# <div align="center">
#
# ### Lab 4
#
# # National Tsing Hua University
#
# #### Spring 2025
#
# #### 11320IEEM 513600
#
# #### Deep Learning and Industrial Applications
#
# ## Lab 4: Predicting Stock Price with Deep Learning
#
# </div>

# %% [markdown]
# ### Introduction
#
# In this lab, we explore the application of time-series datasets using Long Short-Term Memory (LSTM) networks, a type of recurrent neural network, to predict stock prices. Specifically, we will use historical price data from Nvidia to forecast the stock's price for the next day based on the prices of the previous N days. This approach is particularly relevant given the volatile nature of stock markets and the increasing reliance on automated trading systems.
#
# ### Objectives
#
# - To understand the fundamentals of LSTM networks and their application in time-series forecasting.
# - To develop a predictive model that can accurately forecast Nvidia's stock price for the next day using historical data.
#
# ### Dataset
#
# The dataset for this lab is from the "Huge Stock Market Dataset" available on Kaggle. This dataset includes daily prices and volumes for all US stocks and ETFs, with a specific focus on Nvidia (NVDA). The dataset features include:
#
# - **Date**: The recorded data points.
# - **Open**: The price at which the stock first traded upon the opening of an exchange on a given trading day.
# - **High**: The highest price at which the stock traded during the trading day.
# - **Low**: The lowest price at which the stock traded during the trading day.
# - **Close**: The price of the stock at closing time.
# - **Volume**: The number of shares or contracts traded in a security or an entire market during a given period.
# - **OpenInt**: The total number of outstanding derivative contracts, like options or futures. [More details here](https://www.kaggle.com/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/discussion/121096)
#
# ### References
#
# - [Huge Stock Market Dataset](https://www.kaggle.com/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs) for the dataset used in this lab.

# %% [markdown]
# ## A. Checking and Preprocessing

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Deep Learning for Industrial Application /HW4/nvda.us.txt')
df
# Out:
#             Date      Open      High       Low     Close    Volume  OpenInt
# 0     1999-01-22    1.6238    1.8092    1.4379    1.5215  18297633        0
# 1     1999-01-25    1.6423    1.6980    1.5215    1.6793   3445279        0
# 2     1999-01-26    1.6980    1.7350    1.5311    1.5494   2320993        0
# 3     1999-01-27    1.5586    1.5957    1.4660    1.5494   1662658        0
# 4     1999-01-28    1.5494    1.5586    1.5311    1.5401   1540110        0
# ...          ...       ...       ...       ...       ...       ...      ...
# 4728  2017-11-06  207.2000  209.9800  206.7000  209.6300   9731783        0
# 4729  2017-11-07  210.5500  212.9000  210.0560  212.0000  10671815        0
# 4730  2017-11-08  211.8500  212.0000  207.2400  209.1600  13033902        0
# 4731  2017-11-09  205.2700  206.3300  200.3700  205.3200  23895006        0
# 4732  2017-11-10  213.0800  218.6700  211.6300  216.1400  31300857        0
#
# [4733 rows x 7 columns]

# %%
plot = df.plot('Date', 'High', figsize=(15, 5))

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'OpenInt'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4733 entries, 0 to 4732
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     4733 non-null   object
#  1   Open     4733 non-null   float64
#  2   High     4733 non-null   float64
#  3   Low      4733 non-null   float64
#  4   Close    4733 non-null   float64
#  5   Volume   4733 non-null   int64
#  6   OpenInt  4733 non-null   int64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 259.0+ KB

# %%
# checking for null values
df.isnull().sum()
# Out:
# Date       0
# Open       0
# High       0
# Low        0
# Close      0
# Volume     0
# OpenInt    0
# dtype: int64

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (4733, 7)

# %%
df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  4733.000000  4733.000000  4733.000000  4733.000000  4.733000e+03
# mean     20.796242    21.157332    20.420417    20.805404  1.615287e+07
# std      30.236284    30.615622    29.792958    30.263705  1.272446e+07
# min       1.298900     1.317500     1.233900     1.261900  0.000000e+00
# 25%       7.988300     8.247900     7.756400     7.978900  8.181100e+06
# 50%      12.963000    13.238000    12.721000    12.990000  1.390271e+07
# 75%      19.141000    19.418000    18.778000    19.106000  2.051602e+07
# max     213.080000   218.670000   211.630000   216.140000  2.496659e+08
#
#        OpenInt
# count   4733.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0

# %% [markdown]
# #### Converting the DataFrame to a NumPy Array

# %%
def create_sequences(input_data, output_data, window_size, step):
    sequences = []
    labels = []
    for i in range(0, len(input_data) - window_size, step):
        sequences.append(input_data[i:(i + window_size)])
        labels.append(output_data[i + window_size])
    return np.array(sequences), np.array(labels)

# %%
import numpy as np
import torch
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler


# Select features
features = df[['Open', 'Close', 'High', 'Low',]]
labels = df['High'].shift(-1)  # Next day's high price as label

'''
# Normalize the data
scaler = MinMaxScaler()
features_scaled = scaler.fit_transform(features)
'''

X, y = create_sequences(features, labels, window_size=30, step=5)

print(f'Shape of data X: {X.shape}')
print(f'Shape of data y: {y.shape}')

# split the hold-out tests
ind = np.linspace(0, len(X)-1, num=int(len(X)*0.1), dtype=int) # 10% hold-out
x_test = X[ind]
y_test = y[ind]
all_ind = np.arange(len(X))
remains_ind = np.delete(all_ind, ind)

X = X[remains_ind]
y = y[remains_ind]

# shuffle dataset
ind = np.random.permutation(len(X))
X = X[ind]
y = y[ind]
split_point = int(X.shape[0]*0.8)

x_train = X[:split_point]
y_train = y[:split_point]
x_val = X[split_point:]
y_val = y[split_point:]

print(f'Shape of data x_train: {x_train.shape}')
print(f'Shape of data y_train: {y_train.shape}')
print(f'Shape of data x_val: {x_val.shape}')
print(f'Shape of data y_val: {y_val.shape}')
print(f'Shape of data x_test: {x_test.shape}')
print(f'Shape of data y_test: {y_test.shape}')

# Convert to PyTorch tensors
x_train = torch.from_numpy(x_train).float()
y_train = torch.from_numpy(y_train).float()

x_val = torch.from_numpy(x_val).float()
y_val = torch.from_numpy(y_val).float()

x_test = torch.from_numpy(x_test).float()
y_test = torch.from_numpy(y_test).float()

batch_size = 32

# Create datasets
train_dataset = TensorDataset(x_train, y_train)
val_dataset = TensorDataset(x_val, y_val)
test_dataset = TensorDataset(x_test, y_test)

# Create dataloaders
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

print(f'Number of samples in training and validation are {len(train_loader.dataset)} and {len(val_loader.dataset)}.')
# Out:
# Shape of data X: (941, 30, 4)
# Shape of data y: (941,)
# Shape of data x_train: (677, 30, 4)
# Shape of data y_train: (677,)
# Shape of data x_val: (170, 30, 4)
# Shape of data y_val: (170,)
# Shape of data x_test: (94, 30, 4)
# Shape of data y_test: (94,)
# Number of samples in training and validation are 677 and 170.

# %% [markdown]
# ## B. Defining Neural Networks

# %%
import torch.nn as nn

class LSTMModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, output_dim):
        super().__init__()
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.fc(out[:, -1, :])
        return out

# %% [markdown]
# ## C. Training the Neural Network

# %%
# Check your GPU status.
# !nvidia-smi
# Out:
# Tue Apr 29 15:56:29 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR
from tqdm.auto import tqdm

train_losses = []
val_losses = []

epochs = 100

model = LSTMModel(input_dim=4, hidden_dim=500, num_layers=2, output_dim=1).cuda()
print(model)

best_val_loss = float('inf')

criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3)
lr_scheduler = CosineAnnealingLR(optimizer, T_max=epochs, eta_min=0)

for epoch in tqdm(range(epochs)):
    # Training
    model.train()
    total_loss = 0.0

    for features, labels in train_loader:
        features = features.cuda()
        labels = labels.cuda()
        outputs = model(features).squeeze(-1)
        loss = criterion(outputs, labels)
        total_loss += loss.item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    # Learning rate update
    lr_scheduler.step()

    avg_train_loss = total_loss / len(train_loader)

    # Validation
    model.eval()
    total_val_loss = 0.0

    with torch.no_grad():
        for features, labels in val_loader:
            features = features.cuda()
            labels = labels.cuda()
            outputs = model(features).squeeze(-1)
            loss = criterion(outputs, labels)
            total_val_loss += loss.item()

    avg_val_loss = total_val_loss / len(val_loader)

    # Checkpoint
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        torch.save(model.state_dict(), 'best_model.pth')

    print(f'Epoch {epoch+1}/{epochs}, Train loss: {avg_train_loss:.4f}, Val loss: {avg_val_loss:.4f}, Best Val loss: {best_val_loss:.4f}')

    # Store performance
    train_losses.append(avg_train_loss)
    val_losses.append(avg_val_loss)
# Out:
# LSTMModel(
#   (lstm): LSTM(4, 500, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=500, out_features=1, bias=True)
# )
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 1/100, Train loss: 1053.6773, Val loss: 638.4175, Best Val loss: 638.4175
# Epoch 2/100, Train loss: 984.6947, Val loss: 638.0482, Best Val loss: 638.0482
# Epoch 3/100, Train loss: 944.0790, Val loss: 629.3120, Best Val loss: 629.3120
# Epoch 4/100, Train loss: 934.7486, Val loss: 619.9910, Best Val loss: 619.9910
# Epoch 5/100, Train loss: 922.7291, Val loss: 609.1511, Best Val loss: 609.1511
# Epoch 6/100, Train loss: 954.3584, Val loss: 599.1735, Best Val loss: 599.1735
# Epoch 7/100, Train loss: 1010.0178, Val loss: 581.9975, Best Val loss: 581.9975
# Epoch 8/100, Train loss: 835.7814, Val loss: 465.6074, Best Val loss: 465.6074
# Epoch 9/100, Train loss: 682.0327, Val loss: 388.6469, Best Val loss: 388.6469
# Epoch 10/100, Train loss: 681.0876, Val loss: 312.7580, Best Val loss: 312.7580
# Epoch 11/100, Train loss: 466.1818, Val loss: 249.5260, Best Val loss: 249.5260
# Epoch 12/100, Train loss: 392.0863, Val loss: 211.8629, Best Val loss: 211.8629
# Epoch 13/100, Train loss: 337.9998, Val loss: 181.0638, Best Val loss: 181.0638
# Epoch 14/100, Train loss: 337.2666, Val loss: 158.4571, Best Val loss: 158.4571
# Epoch 15/100, Train loss: 269.4228, Val loss: 141.0946, Best Val loss: 141.0946
# Epoch 16/100, Train loss: 270.1803, Val loss: 119.0715, Best Val loss: 119.0715
# Epoch 17/100, Train loss: 190.2487, Val loss: 100.8829, Best Val loss: 100.8829
# Epoch 18/100, Train loss: 245.9003, Val loss: 89.7715, Best Val loss: 89.7715
# Epoch 19/100, Train loss: 146.9526, Val loss: 78.1819, Best Val loss: 78.1819
# Epoch 20/100, Train loss: 131.1243, Val loss: 72.0044, Best Val loss: 72.0044
# Epoch 21/100, Train loss: 120.6910, Val loss: 67.5043, Best Val loss: 67.5043
# Epoch 22/100, Train loss: 109.5471, Val loss: 61.8876, Best Val loss: 61.8876
# Epoch 23/100, Train loss: 103.9844, Val loss: 58.4066, Best Val loss: 58.4066
# Epoch 24/100, Train loss: 96.3773, Val loss: 53.1843, Best Val loss: 53.1843
# Epoch 25/100, Train loss: 87.2567, Val loss: 46.8274, Best Val loss: 46.8274
# Epoch 26/100, Train loss: 80.7122, Val loss: 49.3691, Best Val loss: 46.8274
# Epoch 27/100, Train loss: 73.1154, Val loss: 40.2782, Best Val loss: 40.2782
# Epoch 28/100, Train loss: 66.9681, Val loss: 35.4107, Best Val loss: 35.4107
# Epoch 29/100, Train loss: 62.7652, Val loss: 35.1824, Best Val loss: 35.1824
# Epoch 30/100, Train loss: 59.1066, Val loss: 31.6112, Best Val loss: 31.6112
# Epoch 31/100, Train loss: 54.8179, Val loss: 29.1863, Best Val loss: 29.1863
# Epoch 32/100, Train loss: 54.5702, Val loss: 26.6002, Best Val loss: 26.6002
# Epoch 33/100, Train loss: 45.7353, Val loss: 23.5017, Best Val loss: 23.5017
# Epoch 34/100, Train loss: 51.5992, Val loss: 22.4384, Best Val loss: 22.4384
# Epoch 35/100, Train loss: 39.2981, Val loss: 20.5002, Best Val loss: 20.5002
# Epoch 36/100, Train loss: 39.5155, Val loss: 18.4091, Best Val loss: 18.4091
# Epoch 37/100, Train loss: 33.8334, Val loss: 17.0021, Best Val loss: 17.0021
# Epoch 38/100, Train loss: 33.5640, Val loss: 15.0792, Best Val loss: 15.0792
# Epoch 39/100, Train loss: 30.2992, Val loss: 13.5158, Best Val loss: 13.5158
# Epoch 40/100, Train loss: 27.3609, Val loss: 13.2664, Best Val loss: 13.2664
# Epoch 41/100, Train loss: 29.3151, Val loss: 13.3754, Best Val loss: 13.2664
# Epoch 42/100, Train loss: 23.6906, Val loss: 11.2789, Best Val loss: 11.2789
# Epoch 43/100, Train loss: 22.4771, Val loss: 10.5993, Best Val loss: 10.5993
# Epoch 44/100, Train loss: 20.9411, Val loss: 9.7822, Best Val loss: 9.7822
# Epoch 45/100, Train loss: 19.7694, Val loss: 10.4140, Best Val loss: 9.7822
# Epoch 46/100, Train loss: 19.0569, Val loss: 8.5044, Best Val loss: 8.5044
# Epoch 47/100, Train loss: 20.0243, Val loss: 7.7402, Best Val loss: 7.7402
# Epoch 48/100, Train loss: 17.3889, Val loss: 7.1921, Best Val loss: 7.1921
# Epoch 49/100, Train loss: 16.8257, Val loss: 7.1588, Best Val loss: 7.1588
# Epoch 50/100, Train loss: 16.0136, Val loss: 7.1325, Best Val loss: 7.1325
# Epoch 51/100, Train loss: 15.4124, Val loss: 6.7740, Best Val loss: 6.7740
# Epoch 52/100, Train loss: 19.4598, Val loss: 7.7248, Best Val loss: 6.7740
# Epoch 53/100, Train loss: 14.4478, Val loss: 6.0259, Best Val loss: 6.0259
# Epoch 54/100, Train loss: 13.9764, Val loss: 6.4793, Best Val loss: 6.0259
# Epoch 55/100, Train loss: 13.3835, Val loss: 5.6032, Best Val loss: 5.6032
# Epoch 56/100, Train loss: 13.3534, Val loss: 6.1483, Best Val loss: 5.6032
# Epoch 57/100, Train loss: 13.8681, Val loss: 6.5362, Best Val loss: 5.6032
# Epoch 58/100, Train loss: 12.4128, Val loss: 4.6334, Best Val loss: 4.6334
# Epoch 59/100, Train loss: 11.4894, Val loss: 4.4561, Best Val loss: 4.4561
# Epoch 60/100, Train loss: 11.3721, Val loss: 4.4603, Best Val loss: 4.4561
# Epoch 61/100, Train loss: 11.0995, Val loss: 4.8158, Best Val loss: 4.4561
# Epoch 62/100, Train loss: 10.7811, Val loss: 5.1112, Best Val loss: 4.4561
# Epoch 63/100, Train loss: 10.8148, Val loss: 4.4423, Best Val loss: 4.4423
# Epoch 64/100, Train loss: 10.2302, Val loss: 4.6481, Best Val loss: 4.4423
# Epoch 65/100, Train loss: 10.0375, Val loss: 4.9373, Best Val loss: 4.4423
# Epoch 66/100, Train loss: 9.9088, Val loss: 3.6927, Best Val loss: 3.6927
# Epoch 67/100, Train loss: 9.7926, Val loss: 4.0547, Best Val loss: 3.6927
# Epoch 68/100, Train loss: 9.3851, Val loss: 3.5217, Best Val loss: 3.5217
# Epoch 69/100, Train loss: 9.7337, Val loss: 3.3381, Best Val loss: 3.3381
# Epoch 70/100, Train loss: 9.4472, Val loss: 3.1953, Best Val loss: 3.1953
# Epoch 71/100, Train loss: 9.2253, Val loss: 3.7502, Best Val loss: 3.1953
# Epoch 72/100, Train loss: 9.3809, Val loss: 3.1833, Best Val loss: 3.1833
# Epoch 73/100, Train loss: 8.7891, Val loss: 3.4316, Best Val loss: 3.1833
# Epoch 74/100, Train loss: 8.9986, Val loss: 3.9209, Best Val loss: 3.1833
# Epoch 75/100, Train loss: 9.2009, Val loss: 3.7969, Best Val loss: 3.1833
# Epoch 76/100, Train loss: 8.6895, Val loss: 3.8955, Best Val loss: 3.1833
# Epoch 77/100, Train loss: 8.5601, Val loss: 3.1690, Best Val loss: 3.1690
# Epoch 78/100, Train loss: 8.3769, Val loss: 3.6162, Best Val loss: 3.1690
# Epoch 79/100, Train loss: 8.0799, Val loss: 3.5647, Best Val loss: 3.1690
# Epoch 80/100, Train loss: 7.9912, Val loss: 3.6661, Best Val loss: 3.1690
# Epoch 81/100, Train loss: 7.9553, Val loss: 3.3219, Best Val loss: 3.1690
# Epoch 82/100, Train loss: 7.7313, Val loss: 3.5202, Best Val loss: 3.1690
# Epoch 83/100, Train loss: 7.6962, Val loss: 3.4947, Best Val loss: 3.1690
# Epoch 84/100, Train loss: 7.6172, Val loss: 3.4555, Best Val loss: 3.1690
# Epoch 85/100, Train loss: 8.0352, Val loss: 3.5971, Best Val loss: 3.1690
# Epoch 86/100, Train loss: 7.7024, Val loss: 3.9112, Best Val loss: 3.1690
# Epoch 87/100, Train loss: 7.4875, Val loss: 3.6132, Best Val loss: 3.1690
# Epoch 88/100, Train loss: 7.4134, Val loss: 3.5738, Best Val loss: 3.1690
# Epoch 89/100, Train loss: 7.8728, Val loss: 3.5812, Best Val loss: 3.1690
# Epoch 90/100, Train loss: 7.9813, Val loss: 3.6862, Best Val loss: 3.1690
# Epoch 91/100, Train loss: 7.4561, Val loss: 3.6799, Best Val loss: 3.1690
# Epoch 92/100, Train loss: 7.3882, Val loss: 3.5612, Best Val loss: 3.1690
# Epoch 93/100, Train loss: 7.3343, Val loss: 3.5610, Best Val loss: 3.1690
# Epoch 94/100, Train loss: 7.3441, Val loss: 3.5446, Best Val loss: 3.1690
# Epoch 95/100, Train loss: 7.3378, Val loss: 3.5479, Best Val loss: 3.1690
# Epoch 96/100, Train loss: 7.2785, Val loss: 3.5328, Best Val loss: 3.1690
# Epoch 97/100, Train loss: 7.2693, Val loss: 3.5310, Best Val loss: 3.1690
# Epoch 98/100, Train loss: 7.3107, Val loss: 3.5325, Best Val loss: 3.1690
# Epoch 99/100, Train loss: 7.2711, Val loss: 3.5313, Best Val loss: 3.1690
# Epoch 100/100, Train loss: 7.3067, Val loss: 3.5311, Best Val loss: 3.1690

# %% [markdown]
# #### Visualizing the model performance

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(train_losses)
plt.plot(val_losses)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Train', 'Val'])

plt.show()

# %% [markdown]
# ## D. Evaluating Your Trained Model

# %%
# Load the trained weights
model.load_state_dict(torch.load('best_model.pth'))

# Set the model to evaluation mode
model.eval()

test_correct = 0
test_total = 0

pred_value = []
actual_value = []

with torch.no_grad():
    for features, labels in test_loader:
        features = features.cuda()
        outputs = model(features).squeeze(-1)
        pred_value.append(outputs.cpu())
        actual_value.append(labels)

pred_value = torch.cat(pred_value)
actual_value = torch.cat(actual_value)

# %%
plt.figure(figsize=(10, 5))
plt.plot(pred_value[:])
plt.plot(actual_value[:])
plt.xlabel('Day')
plt.ylabel('Price')
plt.legend(['Pred', 'Actual'])

plt.show()

# %% [markdown]
# <div align="center">
#
# ### Lab 4
#
# # National Tsing Hua University
#
# #### Spring 2025
#
# #### 11320IEEM 513600
#
# #### Deep Learning and Industrial Applications
#
# ## Lab 4: Predicting Stock Price with Deep Learning
#
# </div>

# %% [markdown]
# ### Introduction
#
# In this lab, we explore the application of time-series datasets using Long Short-Term Memory (LSTM) networks, a type of recurrent neural network, to predict stock prices. Specifically, we will use historical price data from Nvidia to forecast the stock's price for the next day based on the prices of the previous N days. This approach is particularly relevant given the volatile nature of stock markets and the increasing reliance on automated trading systems.
#
# ### Objectives
#
# - To understand the fundamentals of LSTM networks and their application in time-series forecasting.
# - To develop a predictive model that can accurately forecast Nvidia's stock price for the next day using historical data.
#
# ### Dataset
#
# The dataset for this lab is from the "Huge Stock Market Dataset" available on Kaggle. This dataset includes daily prices and volumes for all US stocks and ETFs, with a specific focus on Nvidia (NVDA). The dataset features include:
#
# - **Date**: The recorded data points.
# - **Open**: The price at which the stock first traded upon the opening of an exchange on a given trading day.
# - **High**: The highest price at which the stock traded during the trading day.
# - **Low**: The lowest price at which the stock traded during the trading day.
# - **Close**: The price of the stock at closing time.
# - **Volume**: The number of shares or contracts traded in a security or an entire market during a given period.
# - **OpenInt**: The total number of outstanding derivative contracts, like options or futures. [More details here](https://www.kaggle.com/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/discussion/121096)
#
# ### References
#
# - [Huge Stock Market Dataset](https://www.kaggle.com/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs) for the dataset used in this lab.

# %% [markdown]
# ## A. Checking and Preprocessing

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Deep Learning for Industrial Application /HW4/nvda.us.txt')
df
# Out:
#             Date      Open      High       Low     Close    Volume  OpenInt
# 0     1999-01-22    1.6238    1.8092    1.4379    1.5215  18297633        0
# 1     1999-01-25    1.6423    1.6980    1.5215    1.6793   3445279        0
# 2     1999-01-26    1.6980    1.7350    1.5311    1.5494   2320993        0
# 3     1999-01-27    1.5586    1.5957    1.4660    1.5494   1662658        0
# 4     1999-01-28    1.5494    1.5586    1.5311    1.5401   1540110        0
# ...          ...       ...       ...       ...       ...       ...      ...
# 4728  2017-11-06  207.2000  209.9800  206.7000  209.6300   9731783        0
# 4729  2017-11-07  210.5500  212.9000  210.0560  212.0000  10671815        0
# 4730  2017-11-08  211.8500  212.0000  207.2400  209.1600  13033902        0
# 4731  2017-11-09  205.2700  206.3300  200.3700  205.3200  23895006        0
# 4732  2017-11-10  213.0800  218.6700  211.6300  216.1400  31300857        0
#
# [4733 rows x 7 columns]

# %%
plot = df.plot('Date', 'High', figsize=(15, 5))

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'OpenInt'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4733 entries, 0 to 4732
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     4733 non-null   object
#  1   Open     4733 non-null   float64
#  2   High     4733 non-null   float64
#  3   Low      4733 non-null   float64
#  4   Close    4733 non-null   float64
#  5   Volume   4733 non-null   int64
#  6   OpenInt  4733 non-null   int64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 259.0+ KB

# %%
# checking for null values
df.isnull().sum()
# Out:
# Date       0
# Open       0
# High       0
# Low        0
# Close      0
# Volume     0
# OpenInt    0
# dtype: int64

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (4733, 7)

# %%
df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  4733.000000  4733.000000  4733.000000  4733.000000  4.733000e+03
# mean     20.796242    21.157332    20.420417    20.805404  1.615287e+07
# std      30.236284    30.615622    29.792958    30.263705  1.272446e+07
# min       1.298900     1.317500     1.233900     1.261900  0.000000e+00
# 25%       7.988300     8.247900     7.756400     7.978900  8.181100e+06
# 50%      12.963000    13.238000    12.721000    12.990000  1.390271e+07
# 75%      19.141000    19.418000    18.778000    19.106000  2.051602e+07
# max     213.080000   218.670000   211.630000   216.140000  2.496659e+08
#
#        OpenInt
# count   4733.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0

# %% [markdown]
# #### Converting the DataFrame to a NumPy Array

# %%
def create_sequences(input_data, output_data, window_size, step):
    sequences = []
    labels = []
    for i in range(0, len(input_data) - window_size, step):
        sequences.append(input_data[i:(i + window_size)])
        labels.append(output_data[i + window_size])
    return np.array(sequences), np.array(labels)

# %%
import numpy as np
import torch
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler


# Select features
features = df[['Open', 'Close', 'High', 'Low',]]
labels = df['High'].shift(-1)  # Next day's high price as label

'''
# Normalize the data
scaler = MinMaxScaler()
features_scaled = scaler.fit_transform(features)
'''

X, y = create_sequences(features, labels, window_size=30, step=5)

print(f'Shape of data X: {X.shape}')
print(f'Shape of data y: {y.shape}')

# split the hold-out tests
ind = np.linspace(0, len(X)-1, num=int(len(X)*0.1), dtype=int) # 10% hold-out
x_test = X[ind]
y_test = y[ind]
all_ind = np.arange(len(X))
remains_ind = np.delete(all_ind, ind)

X = X[remains_ind]
y = y[remains_ind]

# shuffle dataset
ind = np.random.permutation(len(X))
X = X[ind]
y = y[ind]
split_point = int(X.shape[0]*0.8)

x_train = X[:split_point]
y_train = y[:split_point]
x_val = X[split_point:]
y_val = y[split_point:]

print(f'Shape of data x_train: {x_train.shape}')
print(f'Shape of data y_train: {y_train.shape}')
print(f'Shape of data x_val: {x_val.shape}')
print(f'Shape of data y_val: {y_val.shape}')
print(f'Shape of data x_test: {x_test.shape}')
print(f'Shape of data y_test: {y_test.shape}')

# Convert to PyTorch tensors
x_train = torch.from_numpy(x_train).float()
y_train = torch.from_numpy(y_train).float()

x_val = torch.from_numpy(x_val).float()
y_val = torch.from_numpy(y_val).float()

x_test = torch.from_numpy(x_test).float()
y_test = torch.from_numpy(y_test).float()

batch_size = 32

# Create datasets
train_dataset = TensorDataset(x_train, y_train)
val_dataset = TensorDataset(x_val, y_val)
test_dataset = TensorDataset(x_test, y_test)

# Create dataloaders
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

print(f'Number of samples in training and validation are {len(train_loader.dataset)} and {len(val_loader.dataset)}.')
# Out:
# Shape of data X: (941, 30, 4)
# Shape of data y: (941,)
# Shape of data x_train: (677, 30, 4)
# Shape of data y_train: (677,)
# Shape of data x_val: (170, 30, 4)
# Shape of data y_val: (170,)
# Shape of data x_test: (94, 30, 4)
# Shape of data y_test: (94,)
# Number of samples in training and validation are 677 and 170.

# %% [markdown]
# ## B. Defining Neural Networks

# %%
import torch.nn as nn

class LSTMModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, output_dim):
        super().__init__()
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.fc(out[:, -1, :])
        return out

# %% [markdown]
# ## C. Training the Neural Network

# %%
# Check your GPU status.
# !nvidia-smi
# Out:
# Tue Apr 29 16:38:45 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   65C    P0             29W /   70W |     376MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR
from tqdm.auto import tqdm

train_losses = []
val_losses = []

epochs = 100

model = LSTMModel(input_dim=4, hidden_dim=500, num_layers=2, output_dim=1).cuda()
print(model)

best_val_loss = float('inf')

criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3)
lr_scheduler = CosineAnnealingLR(optimizer, T_max=epochs, eta_min=0)

for epoch in tqdm(range(epochs)):
    # Training
    model.train()
    total_loss = 0.0

    for features, labels in train_loader:
        features = features.cuda()
        labels = labels.cuda()
        outputs = model(features).squeeze(-1)
        loss = criterion(outputs, labels)
        total_loss += loss.item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    # Learning rate update
    lr_scheduler.step()

    avg_train_loss = total_loss / len(train_loader)

    # Validation
    model.eval()
    total_val_loss = 0.0

    with torch.no_grad():
        for features, labels in val_loader:
            features = features.cuda()
            labels = labels.cuda()
            outputs = model(features).squeeze(-1)
            loss = criterion(outputs, labels)
            total_val_loss += loss.item()

    avg_val_loss = total_val_loss / len(val_loader)

    # Checkpoint
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        torch.save(model.state_dict(), 'best_model.pth')

    print(f'Epoch {epoch+1}/{epochs}, Train loss: {avg_train_loss:.4f}, Val loss: {avg_val_loss:.4f}, Best Val loss: {best_val_loss:.4f}')

    # Store performance
    train_losses.append(avg_train_loss)
    val_losses.append(avg_val_loss)
# Out:
# LSTMModel(
#   (lstm): LSTM(4, 500, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=500, out_features=1, bias=True)
# )
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 1/100, Train loss: 1135.2837, Val loss: 396.1049, Best Val loss: 396.1049
# Epoch 2/100, Train loss: 1013.3401, Val loss: 418.4744, Best Val loss: 396.1049
# Epoch 3/100, Train loss: 1044.8057, Val loss: 416.9100, Best Val loss: 396.1049
# Epoch 4/100, Train loss: 1165.2330, Val loss: 411.9222, Best Val loss: 396.1049
# Epoch 5/100, Train loss: 995.4106, Val loss: 409.3359, Best Val loss: 396.1049
# Epoch 6/100, Train loss: 980.5978, Val loss: 388.6105, Best Val loss: 388.6105
# Epoch 7/100, Train loss: 947.5907, Val loss: 335.4498, Best Val loss: 335.4498
# Epoch 8/100, Train loss: 819.1157, Val loss: 223.8791, Best Val loss: 223.8791
# Epoch 9/100, Train loss: 683.2625, Val loss: 167.6498, Best Val loss: 167.6498
# Epoch 10/100, Train loss: 574.0475, Val loss: 126.3947, Best Val loss: 126.3947
# Epoch 11/100, Train loss: 489.9400, Val loss: 91.3541, Best Val loss: 91.3541
# Epoch 12/100, Train loss: 418.9047, Val loss: 68.0938, Best Val loss: 68.0938
# Epoch 13/100, Train loss: 435.6059, Val loss: 49.1273, Best Val loss: 49.1273
# Epoch 14/100, Train loss: 313.8099, Val loss: 33.2871, Best Val loss: 33.2871
# Epoch 15/100, Train loss: 270.8569, Val loss: 24.7632, Best Val loss: 24.7632
# Epoch 16/100, Train loss: 262.6063, Val loss: 40.9140, Best Val loss: 24.7632
# Epoch 17/100, Train loss: 215.1094, Val loss: 11.5169, Best Val loss: 11.5169
# Epoch 18/100, Train loss: 186.3654, Val loss: 13.6708, Best Val loss: 11.5169
# Epoch 19/100, Train loss: 164.0613, Val loss: 8.6936, Best Val loss: 8.6936
# Epoch 20/100, Train loss: 210.5741, Val loss: 7.5101, Best Val loss: 7.5101
# Epoch 21/100, Train loss: 131.2535, Val loss: 8.2796, Best Val loss: 7.5101
# Epoch 22/100, Train loss: 138.0706, Val loss: 10.8212, Best Val loss: 7.5101
# Epoch 23/100, Train loss: 107.7765, Val loss: 12.6453, Best Val loss: 7.5101
# Epoch 24/100, Train loss: 99.5345, Val loss: 15.2621, Best Val loss: 7.5101
# Epoch 25/100, Train loss: 92.5752, Val loss: 11.6251, Best Val loss: 7.5101
# Epoch 26/100, Train loss: 88.3128, Val loss: 19.3913, Best Val loss: 7.5101
# Epoch 27/100, Train loss: 83.0232, Val loss: 5.3620, Best Val loss: 5.3620
# Epoch 28/100, Train loss: 68.9213, Val loss: 7.0590, Best Val loss: 5.3620
# Epoch 29/100, Train loss: 62.1346, Val loss: 5.9816, Best Val loss: 5.3620
# Epoch 30/100, Train loss: 98.9327, Val loss: 3.8669, Best Val loss: 3.8669
# Epoch 31/100, Train loss: 53.1743, Val loss: 8.6280, Best Val loss: 3.8669
# Epoch 32/100, Train loss: 49.0497, Val loss: 8.6183, Best Val loss: 3.8669
# Epoch 33/100, Train loss: 43.3635, Val loss: 4.7522, Best Val loss: 3.8669
# Epoch 34/100, Train loss: 43.4931, Val loss: 4.7743, Best Val loss: 3.8669
# Epoch 35/100, Train loss: 36.7918, Val loss: 4.2154, Best Val loss: 3.8669
# Epoch 36/100, Train loss: 31.9651, Val loss: 4.3852, Best Val loss: 3.8669
# Epoch 37/100, Train loss: 29.2664, Val loss: 4.1875, Best Val loss: 3.8669
# Epoch 38/100, Train loss: 27.3678, Val loss: 4.0076, Best Val loss: 3.8669
# Epoch 39/100, Train loss: 25.7937, Val loss: 2.7701, Best Val loss: 2.7701
# Epoch 40/100, Train loss: 25.4085, Val loss: 6.7703, Best Val loss: 2.7701
# Epoch 41/100, Train loss: 27.3454, Val loss: 6.1971, Best Val loss: 2.7701
# Epoch 42/100, Train loss: 23.5829, Val loss: 4.4965, Best Val loss: 2.7701
# Epoch 43/100, Train loss: 19.8679, Val loss: 3.4199, Best Val loss: 2.7701
# Epoch 44/100, Train loss: 30.4809, Val loss: 3.6936, Best Val loss: 2.7701
# Epoch 45/100, Train loss: 17.3657, Val loss: 3.3109, Best Val loss: 2.7701
# Epoch 46/100, Train loss: 16.8098, Val loss: 4.3817, Best Val loss: 2.7701
# Epoch 47/100, Train loss: 17.0196, Val loss: 2.7511, Best Val loss: 2.7511
# Epoch 48/100, Train loss: 17.1736, Val loss: 4.1004, Best Val loss: 2.7511
# Epoch 49/100, Train loss: 16.7311, Val loss: 4.3524, Best Val loss: 2.7511
# Epoch 50/100, Train loss: 14.6265, Val loss: 3.7178, Best Val loss: 2.7511
# Epoch 51/100, Train loss: 14.3278, Val loss: 3.0674, Best Val loss: 2.7511
# Epoch 52/100, Train loss: 13.8608, Val loss: 3.0822, Best Val loss: 2.7511
# Epoch 53/100, Train loss: 13.4038, Val loss: 2.8188, Best Val loss: 2.7511
# Epoch 54/100, Train loss: 13.3156, Val loss: 2.7189, Best Val loss: 2.7189
# Epoch 55/100, Train loss: 14.9122, Val loss: 3.3857, Best Val loss: 2.7189
# Epoch 56/100, Train loss: 12.7849, Val loss: 3.6772, Best Val loss: 2.7189
# Epoch 57/100, Train loss: 12.5794, Val loss: 3.0221, Best Val loss: 2.7189
# Epoch 58/100, Train loss: 12.3991, Val loss: 3.1272, Best Val loss: 2.7189
# Epoch 59/100, Train loss: 12.2551, Val loss: 2.9552, Best Val loss: 2.7189
# Epoch 60/100, Train loss: 12.0896, Val loss: 3.1655, Best Val loss: 2.7189
# Epoch 61/100, Train loss: 14.6650, Val loss: 3.4444, Best Val loss: 2.7189
# Epoch 62/100, Train loss: 11.8275, Val loss: 3.2062, Best Val loss: 2.7189
# Epoch 63/100, Train loss: 11.6418, Val loss: 3.2887, Best Val loss: 2.7189
# Epoch 64/100, Train loss: 11.5100, Val loss: 2.9426, Best Val loss: 2.7189
# Epoch 65/100, Train loss: 11.3363, Val loss: 3.4037, Best Val loss: 2.7189
# Epoch 66/100, Train loss: 10.6966, Val loss: 3.8110, Best Val loss: 2.7189
# Epoch 67/100, Train loss: 10.3816, Val loss: 3.4364, Best Val loss: 2.7189
# Epoch 68/100, Train loss: 9.6408, Val loss: 2.9571, Best Val loss: 2.7189
# Epoch 69/100, Train loss: 9.2530, Val loss: 2.7671, Best Val loss: 2.7189
# Epoch 70/100, Train loss: 9.0143, Val loss: 2.8171, Best Val loss: 2.7189
# Epoch 71/100, Train loss: 8.8289, Val loss: 2.7915, Best Val loss: 2.7189
# Epoch 72/100, Train loss: 8.5667, Val loss: 2.8325, Best Val loss: 2.7189
# Epoch 73/100, Train loss: 8.4267, Val loss: 2.8117, Best Val loss: 2.7189
# Epoch 74/100, Train loss: 9.5601, Val loss: 2.9902, Best Val loss: 2.7189
# Epoch 75/100, Train loss: 9.5994, Val loss: 2.8737, Best Val loss: 2.7189
# Epoch 76/100, Train loss: 8.6147, Val loss: 3.0264, Best Val loss: 2.7189
# Epoch 77/100, Train loss: 8.2292, Val loss: 3.0811, Best Val loss: 2.7189
# Epoch 78/100, Train loss: 7.9942, Val loss: 2.7974, Best Val loss: 2.7189
# Epoch 79/100, Train loss: 8.6856, Val loss: 2.7992, Best Val loss: 2.7189
# Epoch 80/100, Train loss: 8.1559, Val loss: 3.3289, Best Val loss: 2.7189
# Epoch 81/100, Train loss: 14.7536, Val loss: 2.9528, Best Val loss: 2.7189
# Epoch 82/100, Train loss: 7.6251, Val loss: 3.0160, Best Val loss: 2.7189
# Epoch 83/100, Train loss: 7.4954, Val loss: 2.9681, Best Val loss: 2.7189
# Epoch 84/100, Train loss: 7.4233, Val loss: 2.9552, Best Val loss: 2.7189
# Epoch 85/100, Train loss: 7.3972, Val loss: 2.9509, Best Val loss: 2.7189
# Epoch 86/100, Train loss: 7.3916, Val loss: 2.9529, Best Val loss: 2.7189
# Epoch 87/100, Train loss: 7.2849, Val loss: 2.8647, Best Val loss: 2.7189
# Epoch 88/100, Train loss: 7.2703, Val loss: 2.8628, Best Val loss: 2.7189
# Epoch 89/100, Train loss: 7.2420, Val loss: 2.8743, Best Val loss: 2.7189
# Epoch 90/100, Train loss: 7.2396, Val loss: 2.8900, Best Val loss: 2.7189
# Epoch 91/100, Train loss: 7.2062, Val loss: 2.8547, Best Val loss: 2.7189
# Epoch 92/100, Train loss: 7.1783, Val loss: 2.8585, Best Val loss: 2.7189
# Epoch 93/100, Train loss: 7.1751, Val loss: 2.8561, Best Val loss: 2.7189
# Epoch 94/100, Train loss: 7.1639, Val loss: 2.8362, Best Val loss: 2.7189
# Epoch 95/100, Train loss: 7.1462, Val loss: 2.8448, Best Val loss: 2.7189
# Epoch 96/100, Train loss: 7.1389, Val loss: 2.8405, Best Val loss: 2.7189
# Epoch 97/100, Train loss: 7.1418, Val loss: 2.8400, Best Val loss: 2.7189
# Epoch 98/100, Train loss: 7.1435, Val loss: 2.8376, Best Val loss: 2.7189
# Epoch 99/100, Train loss: 7.1275, Val loss: 2.8394, Best Val loss: 2.7189
# Epoch 100/100, Train loss: 7.1286, Val loss: 2.8394, Best Val loss: 2.7189

# %% [markdown]
# #### Visualizing the model performance

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(train_losses)
plt.plot(val_losses)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Train', 'Val'])

plt.show()

# %% [markdown]
# ## D. Evaluating Your Trained Model

# %%
# Load the trained weights
model.load_state_dict(torch.load('best_model.pth'))

# Set the model to evaluation mode
model.eval()

test_correct = 0
test_total = 0

pred_value = []
actual_value = []

with torch.no_grad():
    for features, labels in test_loader:
        features = features.cuda()
        outputs = model(features).squeeze(-1)
        pred_value.append(outputs.cpu())
        actual_value.append(labels)

pred_value = torch.cat(pred_value)
actual_value = torch.cat(actual_value)

# %%
plt.figure(figsize=(10, 5))
plt.plot(pred_value[:])
plt.plot(actual_value[:])
plt.xlabel('Day')
plt.ylabel('Price')
plt.legend(['Pred', 'Actual'])

plt.show()
